# %% [markdown]
# # Desafio: Usando matrizes RGB (imagens) no Numpy
#
# Toda imagem colorida, para o computador, nada mais é do que um conjunto de três matrizes (vermelha, verde e azul (RGB de red, green e blue)), onde cada uma dessas matriz traz a intensidade da respectiva cor para cada um dos pixels.
# ![image.png](imgs/img5.jpg)
#
# Os valores vão de 0 a 255, onde 0 representa a ausência dessa cor e 255 a intensidade mais forte. Se tivermos um píxel puramente vermelho ele será representado pelos seguintes valores em cada matriz:
#
# - R = 255
# - G = 0
# - B = 0
#
# Na imagem acima, cada célula da matriz representa um píxel. Uma imagem é formada por vários pixels.
#
# Já uma imagem preta e branca ou também chamada de escala de cinza apresenta apenas uma matriz com valores entre 0 e 255 ou entre 0 e 1, onde quanto mais perto de 0, mais escuro é o píxel e quanto mais distante, mais claro.
#
# ![image-2.png](imgs/img6.jpg)
#
# ## Desafio
#
# Para esse desafio, nós iremos abrir uma imagem, inspecionar ela para ver como é representada no computador, e efetuar algumas operações como:
#
# - Transformar em preto e branco
# - Cortar a imagem no meio (tanto na vertical, quanto na horizontal)
# - Apagar o nariz do nosso cachorro
#
# Para fazer o desafio será necessário executar no terminal um dos seguintes comandos:
#
# ```bash
# pip install scikit-image matplotlib
# ```
#
# ou
#
# ```bash
# conda install scikit-image matplotlib
# ```
#
# ou
#
# ```bash
# conda install -c conda-forge scikit-image matplotlib
# ```

# %% [markdown]
# ## Carregando a imagem e visualizando

# %%
from skimage import io
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !pip install scikit-image matplotlib
# Out:
# Collecting scikit-image
#   Using cached scikit_image-0.19.1-cp39-cp39-win_amd64.whl (12.4 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.5.1-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from scikit-image) (1.7.3)
# Collecting networkx>=2.2
#   Using cached networkx-2.6.3-py3-none-any.whl (1.9 MB)
# Requirement already satisfied: numpy>=1.17.0 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from scikit-image) (1.21.2)
# Collecting PyWavelets>=1.1.1
#   Using cached PyWavelets-1.2.0-cp39-cp39-win_amd64.whl (4.2 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from scikit-image) (21.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from scikit-image) (9.0.0)
# Requirement already satisfied: tifffile>=2019.7.26 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from scikit-image) (2021.11.2)
# Collecting imageio>=2.4.1
#   Using cached imageio-2.14.0-py3-none-any.whl (3.3 MB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.3.2-cp39-cp39-win_amd64.whl (52 kB)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (2.8.2)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.28.5-py3-none-any.whl (890 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: six>=1.5 in c:\users\andre\pycharmprojects\pythonproject\venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Installing collected packages: PyWavelets, networkx, kiwisolver, imageio, fonttools, cycler, scikit-image, matplotlib
# Successfully installed PyWavelets-1.2.0 cycler-0.11.0 fonttools-4.28.5 imageio-2.14.0 kiwisolver-1.3.2 matplotlib-3.5.1 networkx-2.6.3 scikit-image-0.19.1

# %%
img = io.imread('shiba-p.jpg') # Carregamento da imagem

print(type(img))

plt.imshow(img) # Exibição da imagem
# Out:
# <class 'numpy.ndarray'>

# %%
img.shape
# Out:
# (640, 640, 3)

# %%
img_copia = img.copy()
plt.imshow(img_copia)

# %% [markdown]
# ## 1. Cortando no meio vertical

# %%
imagem_lateral = img_copia[:640, 320:]
plt.imshow(imagem_lateral)

# %% [markdown]
# ## 2. Cortando no meio horizontal

# %%
imagem_horizontal = img_copia[320:, :640]
plt.imshow(imagem_horizontal)

# %% [markdown]
# ## 3. Apagando o nariz

# %%
nariz_shiba = img.copy()

nariz_shiba[280:360, 335:425] = 255

plt.imshow(nariz_shiba)

# %% [markdown]
# ## 4. Transformando para escala de cinza
#
# A fórmula para transforma para escala de cinza é:
#
# $$0.299 * \text{red} + 0.587 * \text{green} + 0.114 * \text{blue}$$
#
# E para exibir a matriz gerada use:
#
# ```python
# plt.imshow(nome_da_sua_matriz, cmap="gray")
# ```
#
# Obs: Lembre-se que para a escala de cinza o resultado deve ser apenas uma matriz, ou seja, o shape será (640, 640)

# %%
shiba_img = np.array(img_copia)

formula_rgb = [0.299, 0.587, 0.114]

shiba_cinza = np.dot(shiba_img[:, :, :], formula_rgb)

plt.imshow(shiba_cinza, cmap="gray")
